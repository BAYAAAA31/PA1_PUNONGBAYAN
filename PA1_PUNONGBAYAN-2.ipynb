# %%
print ("word rotation")

user_name = input("Please enter your name: ")

def rotate_word(string):
    if len(string) <= 1:
        return string
    return string[1:] + string[0]


print(rotate_word(user_name))
# Out:
# word rotation
# Please enter your name:  helloworld
# elloworldh

# %%
print(rotate_word("python")) 
print(rotate_word("logic"))  
print(rotate_word("Code"))   
print(rotate_word("A"))
# Out:
# ythonp
# ogicl
# odeC
# A

# %%
print ("username maker")

first_name = str(input("Enter First Name: "))
last_name = str (input("Enter Last Name: "))

def make_username (first_name, last_name):
    first_n = first_name.lower().replace(" ","")
    last_n = last_name.lower().replace(" ","")
    return first_n + "." + last_n


print (make_username (first_name, last_name))
# Out:
# username maker
# Enter First Name:  AJ
# Enter Last Name:  PUNONGBAYAN
# aj.punongbayan

# %%
print(make_username ("Ada", "Lovelace"))
print(make_username ("Alan", "Turing"))
print(make_username ("Ana Maria", "De Leon"))
# Out:
# ada.lovelace
# alan.turing
# anamaria.deleon

# %%
print ("Bookend Swapper")

def swap_bookends (items):
    first, *middle, last = items
    return [last] + middle + [first]

print (swap_bookends([1,2,3,4,5,6]))
print (swap_bookends(["red", "green", "blue"]))
print (swap_bookends ([8,3]))
# Out:
# Bookend Swapper
# [6, 2, 3, 4, 5, 1]
# ['blue', 'green', 'red']
# [3, 8]
